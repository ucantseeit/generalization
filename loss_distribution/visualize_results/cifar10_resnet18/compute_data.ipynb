# %%
import os
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np


# 配置函数
def load_config():
	"""
	加载并返回脚本的配置参数。
	"""
	config = {
		'model_dir': '../../model_training_results/cifar10_resnet18',  # 模型存储的文件夹路径
		'model_prefix': 'model_',        # 模型文件名的前缀
		'model_extension': '.pth',                         # 保存模型的文件扩展名
		'cifar10_data_path': '../../pytorch_script/data/cifar10',           # CIFAR-10 数据集存储路径
		'batch_size': 64,                                 # DataLoader 的批次大小
		'num_workers': 2                                  # DataLoader 的工作进程数
	}
	return config

# 数据加载函数
def load_cifar10_data(data_path, batch_size, num_workers):
	"""
	加载 CIFAR-10 数据集并返回训练和测试 DataLoader。
	"""
	print(f"正在加载 CIFAR-10 数据集到 {data_path}...")

	# 数据预处理
	transform = transforms.Compose([
		transforms.ToTensor(),
		transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)) # CIFAR-10 的均值和标准差
	])

	try:
		train_dataset = torchvision.datasets.CIFAR10(root=data_path, train=True, download=True, transform=transform)
		test_dataset = torchvision.datasets.CIFAR10(root=data_path, train=False, download=True, transform=transform)

		train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=False, num_workers=num_workers)
		test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=num_workers)

		print("CIFAR-10 数据集加载成功！")
		return train_loader, test_loader
	except Exception as e:
		print(f"加载 CIFAR-10 数据集时发生错误：{e}")
		print("请检查 CIFAR10_DATA_PATH 是否正确，并确保网络连接正常以便下载数据集。")
		return None, None

# 模型定义函数
def get_resnet18_cifar10():
	"""
	返回一个为 CIFAR-10 任务定制的 ResNet-18 模型实例。
	"""
	model = torchvision.models.resnet18(weights=None) # 不加载预训练权重
	# CIFAR-10 有 10 个类别，因此修改最后一层全连接层
	num_ftrs = model.fc.in_features
	model.fc = nn.Linear(num_ftrs, 10) # 10 是 CIFAR-10 的类别数
	return model

# 模型加载函数
def load_model_state_dict(model_path, device):
	# 实例化模型并加载状态字典
	model = get_resnet18_cifar10().to(device)
	
	checkpoint = torch.load(model_path, map_location=device, weights_only=False)

	# 核心修改：检查加载的内容，并提取 model 的 state_dict
	if isinstance(checkpoint, dict) and 'model' in checkpoint:
		# 如果保存的是一个包含 'model' 键的字典
		print(f"  从字典中提取模型状态字典...")
		model_state_dict = checkpoint['model']
	elif isinstance(checkpoint, dict) and 'state_dict' in checkpoint:
		# 有些框架会把模型的state_dict放在'state_dict'键下
		print(f"  从字典中提取 'state_dict' 键...")
		model_state_dict = checkpoint['state_dict']
	else:
		# 如果直接保存的就是 state_dict
		print(f"  直接加载模型状态字典...")
		model_state_dict = checkpoint
	
	model.load_state_dict(model_state_dict)
	return model



# 模型评估函数
def evaluate_model_performance(model_path, data_loader, device):
	try:
		model = load_model_state_dict(model_path, device)
		model.eval() # 设置模型为评估模式

		correct = 0
		total_loss = 0
		total = 0
		criterion = nn.CrossEntropyLoss()
		with torch.no_grad(): # 在评估时不计算梯度
			for images, labels in data_loader:
				images, labels = images.to(device), labels.to(device)
				outputs = model(images)

				loss = criterion(outputs, labels)
				total_loss += loss.item() * images.size(0)

				_, predicted = torch.max(outputs.data, 1)
				correct += (predicted == labels).sum().item()

				total += labels.size(0)
		
		accuracy = 100 * correct / total
		return accuracy, total_loss
	except Exception as e:
		print(f"评估模型 {model_path} 时发生错误：{e}")
		return None

# 模型文件管理函数
def get_sorted_model_paths(model_dir, model_prefix, model_extension):
	"""
	扫描模型目录，获取所有符合命名约定的模型文件路径，并按纪元排序。
	返回一个 (epoch, model_path) 元组的列表。
	"""
	model_files = []
	if not os.path.exists(model_dir):
		print(f"模型目录 {model_dir} 不存在。请确保模型已保存到此目录。")
		os.makedirs(model_dir) # 尝试创建目录，避免后续错误
		return []

	for f_name in os.listdir(model_dir):
		if f_name.startswith(model_prefix) and f_name.endswith(model_extension):
			try:
				# 从文件名中提取 epoch 号码 (例如 'resnet18_cifar10_epoch_X.pt' -> X)
				epoch_str = f_name.replace(model_prefix, '').replace(model_extension, '')
				epoch = int(epoch_str)
				model_files.append((epoch, os.path.join(model_dir, f_name)))
			except ValueError:
				print(f"跳过无法解析的MODEL_PREFIX或MODEL_EXTENSION文件名：{f_name}")
				continue
	
	model_files.sort(key=lambda x: x[0]) # 按 epoch 排序
	return model_files

# %%
import seaborn as sns

config = load_config()
device = torch.device("cuda")

# 加载数据
train_loader, test_loader = load_cifar10_data(
	config['cifar10_data_path'], config['batch_size'], config['num_workers']
)
if train_loader is None or test_loader is None:
	print("数据加载失败，程序终止。")

# 获取排序后的模型文件路径
sorted_model_paths = get_sorted_model_paths(
	config['model_dir'], config['model_prefix'], config['model_extension']
)

if not sorted_model_paths:
	print("没有找到符合条件或能成功加载的模型文件。请检查 MODEL_DIR, MODEL_PREFIX 和 MODEL_EXTENSION 设置。")

epochs = []
train_accuracies = []
test_accuracies = []
train_losses = []
test_losses = []

print("\n开始逐个评估模型...")
for epoch, model_path in sorted_model_paths:
	print(f"\n正在评估模型：{model_path} (纪元: {epoch})")
	
	# 评估训练集性能
	train_acc, train_loss = evaluate_model_performance(model_path, train_loader, device)
	if train_acc is not None:
		train_accuracies.append(train_acc)
		train_losses.append(train_loss)
		print(f"  training acc = {train_acc:.2f}%")
		print(f"  training loss = {train_loss:.2f}")
	else:
		print("  训练集评估失败，跳过。")
		continue # 如果训练集评估失败，则整个模型跳过

	# 评估测试集性能
	test_acc, test_loss = evaluate_model_performance(model_path, test_loader, device)
	if test_acc is not None:
		test_accuracies.append(test_acc)
		test_losses.append(test_loss)
		print(f"  test acc = {test_acc:.2f}%")
		print(f"  test loss = {train_loss:.2f}")
	else:
		print("  测试集评估失败，跳过。")
		continue # 如果测试集评估失败，则整个模型跳过

	epochs.append(epoch)
# Out:
# 正在加载 CIFAR-10 数据集到 ../../pytorch_script/data/cifar10...
# CIFAR-10 数据集加载成功！
#
# 开始逐个评估模型...
#
# 正在评估模型：../../model_training_results/cifar10_resnet18/model_0.pth (纪元: 0)
#   从字典中提取模型状态字典...
#   training acc = 40.80%
#   training loss = 80584.39%
#   从字典中提取模型状态字典...
#   test acc = 40.58%
#   test loss = 80584.39%
#
# 正在评估模型：../../model_training_results/cifar10_resnet18/model_1.pth (纪元: 1)
#   从字典中提取模型状态字典...
#   training acc = 45.50%
#   training loss = 75667.66%
#   从字典中提取模型状态字典...
#   test acc = 45.38%
#   test loss = 75667.66%
#
# 正在评估模型：../../model_training_results/cifar10_resnet18/model_2.pth (纪元: 2)
#   从字典中提取模型状态字典...
#   training acc = 55.61%
#   training loss = 61917.07%
#   从字典中提取模型状态字典...
#   test acc = 55.33%
#   test loss = 61917.07%
#
# 正在评估模型：../../model_training_results/cifar10_resnet18/model_3.pth (纪元: 3)
#   从字典中提取模型状态字典...
#   training acc = 62.35%
#   training loss = 53391.23%
#   从字典中提取模型状态字典...
#   test acc = 62.08%
#   test loss = 53391.23%
#
# 正在评估模型：../../model_training_results/cifar10_resnet18/model_4.pth (纪元: 4)
#   从字典中提取模型状态字典...
#   training acc = 64.59%
#   training loss = 50339.77%
#   从字典中提取模型状态字典...
#   test acc = 63.84%
#   test loss = 50339.77%
#
# 正在评估模型：../../model_training_results/cifar10_resnet18/model_5.pth (纪元: 5)
#   从字典中提取模型状态字典...
#   training acc = 63.31%
#   training loss = 52228.43%
#   从字典中提取模型状态字典...
#   test acc = 62.61%
#   test loss = 52228.43%
#
# 正在评估模型：../../model_training_results/cifar10_resnet18/model_6.pth (纪元: 6)
#   从字典中提取模型状态字典...
#   training acc = 68.50%
#   training loss = 45506.76%
#   从字典中提取模型状态字典...
#   test acc = 67.69%
#   test loss = 45506.76%
#
# 正在评估模型：../../model_training_results/cifar10_resnet18/model_7.pth (纪元: 7)
#   从字典中提取模型状态字典...
#   training acc = 64.76%
#   training loss = 53093.37%
#   从字典中提取模型状态字典...
#   test acc = 63.51%
#   test loss = 53093.37%
#
# 正在评估模型：../../model_training_results/cifar10_resnet18/model_8.pth (纪元: 8)
#   从字典中提取模型状态字典...
#   training acc = 67.80%
#   training loss = 46674.70%
#   从字典中提取模型状态字典...
#   test acc = 66.02%
#   test loss = 46674.70%
#
# 正在评估模型：../../model_training_results/cifar10_resnet18/model_9.pth (纪元: 9)
#   从字典中提取模型状态字典...
#   training acc = 67.98%
#   training loss = 49162.20%
#   从字典中提取模型状态字典...
#   test acc = 65.57%
#   test loss = 49162.20%
#
# 正在评估模型：../../model_training_results/cifar10_resnet18/model_10.pth (纪元: 10)
#   从字典中提取模型状态字典...
#   training acc = 65.26%
#   training loss = 52021.57%
#   从字典中提取模型状态字典...
#   test acc = 63.51%
#   test loss = 52021.57%
#
# 正在评估模型：../../model_training_results/cifar10_resnet18/model_12.pth (纪元: 12)
#   从字典中提取模型状态字典...
#   training acc = 71.79%
#   training loss = 41382.73%
#   从字典中提取模型状态字典...
#   test acc = 69.79%
#   test loss = 41382.73%
#
# 正在评估模型：../../model_training_results/cifar10_resnet18/model_14.pth (纪元: 14)
#   从字典中提取模型状态字典...
#   training acc = 77.41%
#   training loss = 32870.83%
#   从字典中提取模型状态字典...
#   test acc = 75.38%
#   test loss = 32870.83%
#
# 正在评估模型：../../model_training_results/cifar10_resnet18/model_16.pth (纪元: 16)
#   从字典中提取模型状态字典...
#   training acc = 73.68%
#   training loss = 37983.39%
#   从字典中提取模型状态字典...
#   test acc = 71.99%
#   test loss = 37983.39%
#
# 正在评估模型：../../model_training_results/cifar10_resnet18/model_18.pth (纪元: 18)
#   从字典中提取模型状态字典...
#   training acc = 74.44%
#   training loss = 38197.11%
#   从字典中提取模型状态字典...
#   test acc = 72.28%
#   test loss = 38197.11%
#
# 正在评估模型：../../model_training_results/cifar10_resnet18/model_20.pth (纪元: 20)
#   从字典中提取模型状态字典...
#   training acc = 73.24%
#   training loss = 39671.68%
#   从字典中提取模型状态字典...
#   test acc = 71.39%
#   test loss = 39671.68%
#
# 正在评估模型：../../model_training_results/cifar10_resnet18/model_22.pth (纪元: 22)
#   从字典中提取模型状态字典...
#   training acc = 75.87%
#   training loss = 34819.37%
#   从字典中提取模型状态字典...
#   test acc = 73.70%
#   test loss = 34819.37%
#
# 正在评估模型：../../model_training_results/cifar10_resnet18/model_24.pth (纪元: 24)
#   从字典中提取模型状态字典...
#   training acc = 74.77%
#   training loss = 37355.79%
#   从字典中提取模型状态字典...
#   test acc = 72.45%
#   test loss = 37355.79%
#
# 正在评估模型：../../model_training_results/cifar10_resnet18/model_26.pth (纪元: 26)
#   从字典中提取模型状态字典...
#   training acc = 74.39%
#   training loss = 38211.07%
#   从字典中提取模型状态字典...
#   test acc = 72.74%
#   test loss = 38211.07%
#
# 正在评估模型：../../model_training_results/cifar10_resnet18/model_28.pth (纪元: 28)
#   从字典中提取模型状态字典...
#   training acc = 76.84%
#   training loss = 33193.02%
#   从字典中提取模型状态字典...
#   test acc = 74.24%
#   test loss = 33193.02%
#
# 正在评估模型：../../model_training_results/cifar10_resnet18/model_30.pth (纪元: 30)
#   从字典中提取模型状态字典...
#   training acc = 76.45%
#   training loss = 34887.81%
#   从字典中提取模型状态字典...
#   test acc = 74.06%
#   test loss = 34887.81%
#
# 正在评估模型：../../model_training_results/cifar10_resnet18/model_35.pth (纪元: 35)
#   从字典中提取模型状态字典...
#   training acc = 76.03%
#   training loss = 35192.16%
#   从字典中提取模型状态字典...
#   test acc = 74.36%
#   test loss = 35192.16%
#
# 正在评估模型：../../model_training_results/cifar10_resnet18/model_40.pth (纪元: 40)
#   从字典中提取模型状态字典...
#   training acc = 78.67%
#   training loss = 31642.28%
#   从字典中提取模型状态字典...
#   test acc = 76.51%
#   test loss = 31642.28%
#
# 正在评估模型：../../model_training_results/cifar10_resnet18/model_45.pth (纪元: 45)
#   从字典中提取模型状态字典...
#   training acc = 73.27%
#   training loss = 40595.62%
#   从字典中提取模型状态字典...
#   test acc = 70.49%
#   test loss = 40595.62%
#
# 正在评估模型：../../model_training_results/cifar10_resnet18/model_50.pth (纪元: 50)
#   从字典中提取模型状态字典...
#   training acc = 76.24%
#   training loss = 34730.26%
#   从字典中提取模型状态字典...
#   test acc = 73.55%
#   test loss = 34730.26%
#
# 正在评估模型：../../model_training_results/cifar10_resnet18/model_55.pth (纪元: 55)
#   从字典中提取模型状态字典...
#   training acc = 79.30%
#   training loss = 29824.38%
#   从字典中提取模型状态字典...
#   test acc = 76.38%
#   test loss = 29824.38%
#
# 正在评估模型：../../model_training_results/cifar10_resnet18/model_60.pth (纪元: 60)
#   从字典中提取模型状态字典...
#   training acc = 74.72%
#   training loss = 37211.55%
#   从字典中提取模型状态字典...
#   test acc = 71.72%
#   test loss = 37211.55%
#
# 正在评估模型：../../model_training_results/cifar10_resnet18/model_65.pth (纪元: 65)
#   从字典中提取模型状态字典...
#   training acc = 79.90%
#   training loss = 29134.52%
#   从字典中提取模型状态字典...
#   test acc = 76.68%
#   test loss = 29134.52%
#
# 正在评估模型：../../model_training_results/cifar10_resnet18/model_70.pth (纪元: 70)
#   从字典中提取模型状态字典...
#   training acc = 79.39%
#   training loss = 30247.90%
#   从字典中提取模型状态字典...
#   test acc = 76.02%
#   test loss = 30247.90%
#
# 正在评估模型：../../model_training_results/cifar10_resnet18/model_75.pth (纪元: 75)
#   从字典中提取模型状态字典...
#   training acc = 79.78%
#   training loss = 29363.41%
#   从字典中提取模型状态字典...
#   test acc = 76.78%
#   test loss = 29363.41%
#
# 正在评估模型：../../model_training_results/cifar10_resnet18/model_80.pth (纪元: 80)
#   从字典中提取模型状态字典...
#   training acc = 78.73%
#   training loss = 31059.30%
#   从字典中提取模型状态字典...
#   test acc = 75.35%
#   test loss = 31059.30%
#
# 正在评估模型：../../model_training_results/cifar10_resnet18/model_85.pth (纪元: 85)
#   从字典中提取模型状态字典...
#   training acc = 76.00%
#   training loss = 35314.54%
#   从字典中提取模型状态字典...
#   test acc = 73.52%
#   test loss = 35314.54%
#
# 正在评估模型：../../model_training_results/cifar10_resnet18/model_90.pth (纪元: 90)
#   从字典中提取模型状态字典...
#   training acc = 75.22%
#   training loss = 34698.37%
#   从字典中提取模型状态字典...
#   test acc = 73.12%
#   test loss = 34698.37%
#
# 正在评估模型：../../model_training_results/cifar10_resnet18/model_95.pth (纪元: 95)
#   从字典中提取模型状态字典...
#   training acc = 76.33%
#   training loss = 35990.04%
#   从字典中提取模型状态字典...
#   test acc = 72.73%
#   test loss = 35990.04%
#
# 正在评估模型：../../model_training_results/cifar10_resnet18/model_100.pth (纪元: 100)
#   从字典中提取模型状态字典...
#   training acc = 77.17%
#   training loss = 34778.31%
#   从字典中提取模型状态字典...
#   test acc = 74.78%
#   test loss = 34778.31%
#
# 正在评估模型：../../model_training_results/cifar10_resnet18/model_110.pth (纪元: 110)
#   从字典中提取模型状态字典...
#   training acc = 79.60%
#   training loss = 29610.41%
#   从字典中提取模型状态字典...
#   test acc = 76.74%
#   test loss = 29610.41%
#
# 正在评估模型：../../model_training_results/cifar10_resnet18/model_120.pth (纪元: 120)
#   从字典中提取模型状态字典...
#   training acc = 77.59%
#   training loss = 33656.06%
#   从字典中提取模型状态字典...
#   test acc = 74.85%
#   test loss = 33656.06%
#
# 正在评估模型：../../model_training_results/cifar10_resnet18/model_130.pth (纪元: 130)
#   从字典中提取模型状态字典...
#   training acc = 81.16%
#   training loss = 27193.28%
#   从字典中提取模型状态字典...
#   test acc = 77.91%
#   test loss = 27193.28%
#
# 正在评估模型：../../model_training_results/cifar10_resnet18/model_140.pth (纪元: 140)
#   从字典中提取模型状态字典...
#   training acc = 78.86%
#   training loss = 30864.01%
#   从字典中提取模型状态字典...
#   test acc = 75.86%
#   test loss = 30864.01%
#
# 正在评估模型：../../model_training_results/cifar10_resnet18/model_150.pth (纪元: 150)
#   从字典中提取模型状态字典...
#   training acc = 78.60%
#   training loss = 31706.55%
#   从字典中提取模型状态字典...
#   test acc = 75.83%
#   test loss = 31706.55%
#
# 正在评估模型：../../model_training_results/cifar10_resnet18/model_160.pth (纪元: 160)
#   从字典中提取模型状态字典...
#   training acc = 81.58%
#   training loss = 26208.97%
#   从字典中提取模型状态字典...
#   test acc = 78.23%
#   test loss = 26208.97%
#
# 正在评估模型：../../model_training_results/cifar10_resnet18/model_170.pth (纪元: 170)
#   从字典中提取模型状态字典...
#   training acc = 83.30%
#   training loss = 24251.83%
#   从字典中提取模型状态字典...
#   test acc = 79.34%
#   test loss = 24251.83%
#
# 正在评估模型：../../model_training_results/cifar10_resnet18/model_180.pth (纪元: 180)
#   从字典中提取模型状态字典...
#   training acc = 83.63%
#   training loss = 23571.66%
#   从字典中提取模型状态字典...
#   test acc = 79.66%
#   test loss = 23571.66%
#
# 正在评估模型：../../model_training_results/cifar10_resnet18/model_190.pth (纪元: 190)
#   从字典中提取模型状态字典...
#   training acc = 83.65%
#   training loss = 23826.27%
#   从字典中提取模型状态字典...
#   test acc = 79.43%
#   test loss = 23826.27%
#
# 正在评估模型：../../model_training_results/cifar10_resnet18/model_200.pth (纪元: 200)
#   从字典中提取模型状态字典...
#   training acc = 83.19%
#   training loss = 23928.21%
#   从字典中提取模型状态字典...
#   test acc = 79.34%
#   test loss = 23928.21%
#
# 正在评估模型：../../model_training_results/cifar10_resnet18/model_210.pth (纪元: 210)
#   从字典中提取模型状态字典...
#   training acc = 86.66%
#   training loss = 19070.63%
#   从字典中提取模型状态字典...
#   test acc = 81.56%
#   test loss = 19070.63%
#
# 正在评估模型：../../model_training_results/cifar10_resnet18/model_220.pth (纪元: 220)
#   从字典中提取模型状态字典...
#   training acc = 86.90%
#   training loss = 18976.48%
#   从字典中提取模型状态字典...
#   test acc = 81.40%
#   test loss = 18976.48%
#
# 正在评估模型：../../model_training_results/cifar10_resnet18/model_230.pth (纪元: 230)
#   从字典中提取模型状态字典...
#   training acc = 86.78%
#   training loss = 19025.37%
#   从字典中提取模型状态字典...
#   test acc = 81.59%
#   test loss = 19025.37%
#
# 正在评估模型：../../model_training_results/cifar10_resnet18/model_240.pth (纪元: 240)
#   从字典中提取模型状态字典...
#   training acc = 87.42%
#   training loss = 18069.56%
#   从字典中提取模型状态字典...
#   test acc = 81.90%
#   test loss = 18069.56%
#
# 正在评估模型：../../model_training_results/cifar10_resnet18/model_250.pth (纪元: 250)
#   从字典中提取模型状态字典...
#   training acc = 88.26%
#   training loss = 16868.46%
#   从字典中提取模型状态字典...
#   test acc = 82.46%
#   test loss = 16868.46%
#
# 正在评估模型：../../model_training_results/cifar10_resnet18/model_260.pth (纪元: 260)
#   从字典中提取模型状态字典...
#   training acc = 89.32%
#   training loss = 15199.58%
#   从字典中提取模型状态字典...
#   test acc = 83.68%
#   test loss = 15199.58%
#
# 正在评估模型：../../model_training_results/cifar10_resnet18/model_270.pth (纪元: 270)
#   从字典中提取模型状态字典...
#   training acc = 89.77%
#   training loss = 14792.37%
#   从字典中提取模型状态字典...
#   test acc = 83.13%
#   test loss = 14792.37%
#
# 正在评估模型：../../model_training_results/cifar10_resnet18/model_280.pth (纪元: 280)
#   从字典中提取模型状态字典...
#   training acc = 90.16%
#   training loss = 13823.82%
#   从字典中提取模型状态字典...
#   test acc = 83.14%
#   test loss = 13823.82%
#
# 正在评估模型：../../model_training_results/cifar10_resnet18/model_290.pth (纪元: 290)
#   从字典中提取模型状态字典...
#   training acc = 92.35%
#   training loss = 10971.32%
#   从字典中提取模型状态字典...
#   test acc = 84.20%
#   test loss = 10971.32%
#
# 正在评估模型：../../model_training_results/cifar10_resnet18/model_300.pth (纪元: 300)
#   从字典中提取模型状态字典...
#   training acc = 91.76%
#   training loss = 11691.92%
#   从字典中提取模型状态字典...
#   test acc = 83.44%
#   test loss = 11691.92%
#
# 正在评估模型：../../model_training_results/cifar10_resnet18/model_310.pth (纪元: 310)
#   从字典中提取模型状态字典...
#   training acc = 92.89%
#   training loss = 10218.46%
#   从字典中提取模型状态字典...
#   test acc = 84.23%
#   test loss = 10218.46%
#
# 正在评估模型：../../model_training_results/cifar10_resnet18/model_320.pth (纪元: 320)
#   从字典中提取模型状态字典...
#   training acc = 94.35%
#   training loss = 8200.21%
#   从字典中提取模型状态字典...
#   test acc = 84.70%
#   test loss = 8200.21%
#
# 正在评估模型：../../model_training_results/cifar10_resnet18/model_330.pth (纪元: 330)
#   从字典中提取模型状态字典...
#   training acc = 95.38%
#   training loss = 6506.46%
#   从字典中提取模型状态字典...
#   test acc = 85.40%
#   test loss = 6506.46%
#
# 正在评估模型：../../model_training_results/cifar10_resnet18/model_340.pth (纪元: 340)
#   从字典中提取模型状态字典...
#   training acc = 96.05%
#   training loss = 5523.29%
#   从字典中提取模型状态字典...
#   test acc = 85.30%
#   test loss = 5523.29%
#
# 正在评估模型：../../model_training_results/cifar10_resnet18/model_350.pth (纪元: 350)
#   从字典中提取模型状态字典...
#   training acc = 97.58%
#   training loss = 3556.05%
#   从字典中提取模型状态字典...
#   test acc = 85.77%
#   test loss = 3556.05%
#
# 正在评估模型：../../model_training_results/cifar10_resnet18/model_360.pth (纪元: 360)
#   从字典中提取模型状态字典...
#   training acc = 98.60%
#   training loss = 2087.28%
#   从字典中提取模型状态字典...
#   test acc = 86.59%
#   test loss = 2087.28%
#
# 正在评估模型：../../model_training_results/cifar10_resnet18/model_370.pth (纪元: 370)
#   从字典中提取模型状态字典...
#   training acc = 98.95%
#   training loss = 1641.83%
#   从字典中提取模型状态字典...
#   test acc = 87.08%
#   test loss = 1641.83%
#
# 正在评估模型：../../model_training_results/cifar10_resnet18/model_380.pth (纪元: 380)
#   从字典中提取模型状态字典...
#   training acc = 99.33%
#   training loss = 1053.59%
#   从字典中提取模型状态字典...
#   test acc = 87.53%
#   test loss = 1053.59%
#
# 正在评估模型：../../model_training_results/cifar10_resnet18/model_390.pth (纪元: 390)
#   从字典中提取模型状态字典...
#   training acc = 99.40%
#   training loss = 984.44%
#   从字典中提取模型状态字典...
#   test acc = 87.48%
#   test loss = 984.44%
#
# 正在评估模型：../../model_training_results/cifar10_resnet18/model_400.pth (纪元: 400)
#   从字典中提取模型状态字典...
#   training acc = 99.44%
#   training loss = 919.21%
#   从字典中提取模型状态字典...
#   test acc = 87.56%
#   test loss = 919.21%
#
# 正在评估模型：../../model_training_results/cifar10_resnet18/model_410.pth (纪元: 410)
#   从字典中提取模型状态字典...
#   training acc = 99.51%
#   training loss = 844.23%
#   从字典中提取模型状态字典...
#   test acc = 87.63%
#   test loss = 844.23%
#
# 正在评估模型：../../model_training_results/cifar10_resnet18/model_420.pth (纪元: 420)
#   从字典中提取模型状态字典...
#   training acc = 99.36%
#   training loss = 992.01%
#   从字典中提取模型状态字典...
#   test acc = 87.33%
#   test loss = 992.01%
#
# 正在评估模型：../../model_training_results/cifar10_resnet18/model_430.pth (纪元: 430)
#   从字典中提取模型状态字典...
#   training acc = 99.17%
#   training loss = 1297.62%
#   从字典中提取模型状态字典...
#   test acc = 87.06%
#   test loss = 1297.62%
#
# 正在评估模型：../../model_training_results/cifar10_resnet18/model_440.pth (纪元: 440)
#   从字典中提取模型状态字典...
#   training acc = 98.29%
#   training loss = 2471.22%
#   从字典中提取模型状态字典...
#   test acc = 85.70%
#   test loss = 2471.22%
#
# 正在评估模型：../../model_training_results/cifar10_resnet18/model_450.pth (纪元: 450)
#   从字典中提取模型状态字典...
#   training acc = 97.14%
#   training loss = 4111.04%
#   从字典中提取模型状态字典...
#   test acc = 85.78%
#   test loss = 4111.04%
#
# 正在评估模型：../../model_training_results/cifar10_resnet18/model_460.pth (纪元: 460)
#   从字典中提取模型状态字典...
#   training acc = 95.30%
#   training loss = 6756.29%
#   从字典中提取模型状态字典...
#   test acc = 84.45%
#   test loss = 6756.29%
#
# 正在评估模型：../../model_training_results/cifar10_resnet18/model_470.pth (纪元: 470)
#   从字典中提取模型状态字典...
#   training acc = 94.84%
#   training loss = 7440.17%
#   从字典中提取模型状态字典...
#   test acc = 84.46%
#   test loss = 7440.17%
#
# 正在评估模型：../../model_training_results/cifar10_resnet18/model_480.pth (纪元: 480)
#   从字典中提取模型状态字典...
#   training acc = 93.03%
#   training loss = 10079.74%
#   从字典中提取模型状态字典...
#   test acc = 83.31%
#   test loss = 10079.74%
#
# 正在评估模型：../../model_training_results/cifar10_resnet18/model_490.pth (纪元: 490)
#   从字典中提取模型状态字典...
#   training acc = 93.32%
#   training loss = 9569.28%
#   从字典中提取模型状态字典...
#   test acc = 83.96%
#   test loss = 9569.28%
#
# 正在评估模型：../../model_training_results/cifar10_resnet18/model_500.pth (纪元: 500)
#   从字典中提取模型状态字典...
#   training acc = 93.43%
#   training loss = 9391.83%
#   从字典中提取模型状态字典...
#   test acc = 84.44%
#   test loss = 9391.83%

# %%
np.save('train_accuracies.npy', np.array(train_accuracies))
np.save('test_accuracies.npy', np.array(test_accuracies))
np.save('train_losses.npy', np.array(train_losses))
np.save('test_losses.npy', np.array(test_losses))

# %%
def model_losses(model, data_loader):
  losses = []
  model.eval()
  for images, labels in data_loader:
    images, labels = images.to(device), labels.to(device)
    outputs = model(images)
    loss = torch.nn.functional.cross_entropy(outputs, labels)
    losses.append(loss.item())
  return losses

# %%
all_model_train_losses = {}
all_model_test_losses = {}

for epoch, model_path in sorted_model_paths:
	print(epoch)
	model = load_model_state_dict(model_path, device)
	all_model_train_losses[epoch] = model_losses(model, train_loader)
	all_model_test_losses[epoch] = model_losses(model, test_loader)
# Out:
# 0
#   从字典中提取模型状态字典...
# 1
#   从字典中提取模型状态字典...
# 2
#   从字典中提取模型状态字典...
# 3
#   从字典中提取模型状态字典...
# 4
#   从字典中提取模型状态字典...
# 5
#   从字典中提取模型状态字典...
# 6
#   从字典中提取模型状态字典...
# 7
#   从字典中提取模型状态字典...
# 8
#   从字典中提取模型状态字典...
# 9
#   从字典中提取模型状态字典...
# 10
#   从字典中提取模型状态字典...
# 12
#   从字典中提取模型状态字典...
# 14
#   从字典中提取模型状态字典...
# 16
#   从字典中提取模型状态字典...
# 18
#   从字典中提取模型状态字典...
# 20
#   从字典中提取模型状态字典...
# 22
#   从字典中提取模型状态字典...
# 24
#   从字典中提取模型状态字典...
# 26
#   从字典中提取模型状态字典...
# 28
#   从字典中提取模型状态字典...
# 30
#   从字典中提取模型状态字典...
# 35
#   从字典中提取模型状态字典...
# 40
#   从字典中提取模型状态字典...
# 45
#   从字典中提取模型状态字典...
# 50
#   从字典中提取模型状态字典...
# 55
#   从字典中提取模型状态字典...
# 60
#   从字典中提取模型状态字典...
# 65
#   从字典中提取模型状态字典...
# 70
#   从字典中提取模型状态字典...
# 75
#   从字典中提取模型状态字典...
# 80
#   从字典中提取模型状态字典...
# 85
#   从字典中提取模型状态字典...
# 90
#   从字典中提取模型状态字典...
# 95
#   从字典中提取模型状态字典...
# 100
#   从字典中提取模型状态字典...
# 110
#   从字典中提取模型状态字典...
# 120
#   从字典中提取模型状态字典...
# 130
#   从字典中提取模型状态字典...
# 140
#   从字典中提取模型状态字典...
# 150
#   从字典中提取模型状态字典...
# 160
#   从字典中提取模型状态字典...
# 170
#   从字典中提取模型状态字典...
# 180
#   从字典中提取模型状态字典...
# 190
#   从字典中提取模型状态字典...
# 200
#   从字典中提取模型状态字典...
# 210
#   从字典中提取模型状态字典...
# 220
#   从字典中提取模型状态字典...
# 230
#   从字典中提取模型状态字典...
# 240
#   从字典中提取模型状态字典...
# 250
#   从字典中提取模型状态字典...
# 260
#   从字典中提取模型状态字典...
# 270
#   从字典中提取模型状态字典...
# 280
#   从字典中提取模型状态字典...
# 290
#   从字典中提取模型状态字典...
# 300
#   从字典中提取模型状态字典...
# 310
#   从字典中提取模型状态字典...
# 320
#   从字典中提取模型状态字典...
# 330
#   从字典中提取模型状态字典...
# 340
#   从字典中提取模型状态字典...
# 350
#   从字典中提取模型状态字典...
# 360
#   从字典中提取模型状态字典...
# 370
#   从字典中提取模型状态字典...
# 380
#   从字典中提取模型状态字典...
# 390
#   从字典中提取模型状态字典...
# 400
#   从字典中提取模型状态字典...
# 410
#   从字典中提取模型状态字典...
# 420
#   从字典中提取模型状态字典...
# 430
#   从字典中提取模型状态字典...
# 440
#   从字典中提取模型状态字典...
# 450
#   从字典中提取模型状态字典...
# 460
#   从字典中提取模型状态字典...
# 470
#   从字典中提取模型状态字典...
# 480
#   从字典中提取模型状态字典...
# 490
#   从字典中提取模型状态字典...
# 500
#   从字典中提取模型状态字典...

# %%
all_model_train_losses1 = {}
all_model_test_losses1 = {}

for k, v in all_model_train_losses.items():
    all_model_train_losses1[k] = np.array(v) / 50000

for k, v in all_model_test_losses.items():
    all_model_test_losses1[k] = np.array(v) / 10000

import pickle
file_path_pickle = "all_model_train_losses.pickle"
with open(file_path_pickle, 'wb') as f: # 注意 'wb' 表示写入二进制
    pickle.dump(all_model_train_losses1, f)

file_path_pickle = "all_model_test_losses.pickle"
with open(file_path_pickle, 'wb') as f: # 注意 'wb' 表示写入二进制
    pickle.dump(all_model_test_losses1, f)

# %%
np.save('epochs.npy', epochs)

# %%
len(train_loader)
# Out:
# 782
